# %%
print("Hello Jupiter")
# Out:
# Hello Jupiter

# %%
This is a markdown cell.
# Out:
#   Cell In[1], line 1
#     This is a markdown cell.
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
